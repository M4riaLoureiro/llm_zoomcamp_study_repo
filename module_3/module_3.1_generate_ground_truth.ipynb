# %% [markdown]
# # Prepare Open AI client object

# %%
from openai import OpenAI

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
client

# %% [markdown]
# # Prepare documents with IDs for GT generation

# %%
import json

# %%
with open("documents.json", "rt") as f_in:
    docs_raw = json.load(f_in)

# %%
documents = []

for course_dict in docs_raw:
    for doc in course_dict["documents"]:
        doc["course"] = course_dict["course"]
        documents.append(doc)

# %%
import hashlib


def generate_document_id(doc):
    # combined = f"{doc['course']}-{doc['question']}"
    combined = f"{doc['course']}-{doc['question']}-{doc['text'][:10]}"
    hash_object = hashlib.md5(combined.encode())
    hash_hex = hash_object.hexdigest()
    document_id = hash_hex[:8]
    return document_id

# %%
for doc in documents:
    doc["id"] = generate_document_id(doc)

# %%
documents[3]
# Out:
# {'text': "You don't need it. You're accepted. You can also just start learning and submitting homework without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#  'section': 'General course-related questions',
#  'question': 'Course - I have registered for the Data Engineering Bootcamp. When can I expect to receive the confirmation email?',
#  'course': 'data-engineering-zoomcamp',
#  'id': '0bbf41ec'}

# %%
from collections import defaultdict

# %%
hashes = defaultdict(list)

for doc in documents:
    doc_id = doc["id"]
    hashes[doc_id].append(doc)

# %%
len(hashes), len(documents)
# Out:
# (947, 948)

# %% [markdown]
# This means that the unique IDs generated are not actually unique and a different method should be used in principle. In this case, this is really a duplicate question so we can just leave it like this.

# %%
for k, values in hashes.items():
    if len(values) > 1:
        print(k, len(values))
# Out:
# 593f7569 2

# %%
hashes["593f7569"]
# Out:
# [{'text': "They both do the same, it's just less typing from the script.\nAsked by Andrew Katoch, Added by Edidiong Esu",
#   'section': '6. Decision Trees and Ensemble Learning',
#   'question': 'Does it matter if we let the Python file create the server or if we run gunicorn directly?',
#   'course': 'machine-learning-zoomcamp',
#   'id': '593f7569'},
#  {'text': "They both do the same, it's just less typing from the script.",
#   'section': '6. Decision Trees and Ensemble Learning',
#   'question': 'Does it matter if we let the Python file create the server or if we run gunicorn directly?',
#   'course': 'machine-learning-zoomcamp',
#   'id': '593f7569'}]

# %%
with open("documents-with-ids.json", "wt") as f_out:
    json.dump(documents, f_out, indent=2)

# %%
# !head documents-with-ids.json
# Out:
# [
#   {
#     "text": "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  \u201cOffice Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon\u2019t forget to register in DataTalks.Club's Slack and join the channel.",
#     "section": "General course-related questions",
#     "question": "Course - When will the course start?",
#     "course": "data-engineering-zoomcamp",
#     "id": "c02e79ef"
#   },
#   {
#     "text": "GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites",

# %% [markdown]
# # Generate ground truth using chatgpt

# %%
prompt_template = """
You emulate a student who's taking our course.
Formulate 5 questions this student might ask based on a FAQ record. The record
should contain the answer to the questions, and the questions should be complete and not too short.
If possible, use as fewer words as possible from the record. 

The record:

section: {section}
question: {question}
answer: {text}

Provide the output in parsable JSON without using code blocks:

["question1", "question2", ..., "question5"]
""".strip()

# %%
def generate_questions(doc):
    prompt = prompt_template.format(**doc)

    response = client.chat.completions.create(
        model="gpt-4o", messages=[{"role": "user", "content": prompt}]
    )

    json_response = response.choices[0].message.content
    return json_response

# %%
from tqdm.auto import tqdm

# %%
results = {}
for doc in tqdm(documents):
    doc_id = doc["id"]
    if doc_id in results:
        continue

    questions = generate_questions(doc)
    results[doc_id] = questions
# Out:
#   0%|          | 0/948 [00:00<?, ?it/s]

# %%
results["1f6520ca"]
# Out:
# '[\n  "What are the course prerequisites?",\n  "Are there any prerequisites I need to know before starting?",\n  "Where can I find details about course requirements?",\n  "Is there a list of prerequisites available for the course?",\n  "Can you tell me about the prerequisites for enrollment?"\n]'

# %%
results["593f7569"]
# Out:
# '[\n  "Is it more efficient to create the server in the Python file or run gunicorn directly?",\n  "What are the benefits of letting the Python script create the server compared to running gunicorn?",\n  "Are there any differences in performance between creating the server in Python file and running gunicorn directly?",\n  "Why might someone choose to let the Python file create the server instead of running gunicorn directly?",\n  "What is a simpler method for starting the server: using the Python script or running gunicorn?"\n]'

# %%
len(results)
# Out:
# 947

# %%
import pickle

# with open('GT_documents.bin', 'wb') as file:
#    pickle.dump(results, file)

with open("GT_documents.bin", "rb") as f_in:
    results = pickle.load(f_in)

# %%
parsed_results = {}

# %%
for doc_id, json_questions in results.items():

    if doc_id in parsed_results:
        continue

    parsed_results[doc_id] = json.loads(json_questions)

# %% [markdown]
# #### Pipeline to correct typos from LLM

# %%
json_questions
# Out:
# '[\n  "Will I still receive a certificate if I miss a major project?",\n  Is missing the midterm detrimental to getting my certificate?",\n  What happens if I skipped the midterm project but want a certificate?",\n  Can I qualify for a certificate despite not completing the midterm project?",\n  If I didn\'t submit the midterm project, is a certificate still an option?"\n]'

# %%
json.loads(
    '[\n  "Will I still receive a certificate if I miss a major project?",\n  "Is missing the midterm detrimental to getting my certificate?",\n  "What happens if I skipped the midterm project but want a certificate?",\n " Can I qualify for a certificate despite not completing the midterm project?",\n  "If I didn\'t submit the midterm project, is a certificate still an option?"\n]'
)
# Out:
# ['Will I still receive a certificate if I miss a major project?',
#  'Is missing the midterm detrimental to getting my certificate?',
#  'What happens if I skipped the midterm project but want a certificate?',
#  ' Can I qualify for a certificate despite not completing the midterm project?',
#  "If I didn't submit the midterm project, is a certificate still an option?"]

# %%
results[doc_id] = (
    '[\n  "Will I still receive a certificate if I miss a major project?",\n  "Is missing the midterm detrimental to getting my certificate?",\n  "What happens if I skipped the midterm project but want a certificate?",\n " Can I qualify for a certificate despite not completing the midterm project?",\n  "If I didn\'t submit the midterm project, is a certificate still an option?"\n]'
)

# %%
parsed_results
# Out:
# {'c02e79ef': ['What is the starting date and time of the course?',
#   "When will the first 'Office Hours' live session be?",
#   "How can I subscribe to the course's public Google Calendar?",
#   'Where should I register before the course starts?',
#   'Which platforms should I join for announcements and discussions?'],
#  '1f6520ca': ['What are the course prerequisites?',
#   'Are there any prerequisites I need to know before starting?',
#   'Where can I find details about course requirements?',
#   'Is there a list of prerequisites available for the course?',
#   'Can you tell me about the prerequisites for enrollment?'],
#  '7842b56a': ['Is it possible to join the course after it has already started?',
#   'Can I participate in the course activities if I register late?',
#   'Am I still eligible to submit homeworks if I miss the registration deadline?',
#   'Are there any deadlines for final projects if I join the course late?',
#   'Can I complete the course without registering from the start?'],
#  '0bbf41ec': ['When will I get the confirmation email for the Data Engineering Bootcamp?',
#   'Is the confirmation email necessary for the Data Engineering Bootcamp?',
#   'Can I start learning and submitting homework without receiving a confirmation email?',
#   'Is registration mandatory to begin the Data Engineering Bootcamp?',
#   'Does the course check registrations before allowing students to start?'],
#  '63394d91': ['What should I set up before the course begins?',
#   'Do I need to install specific software before starting?',
#   'Which Python version is required for this course?',
#   'Is it necessary to have a Google Cloud account before the course?',
#   'Should I check the syllabus and prerequisites beforehand?'],
#  '2ed9b986': ['How many Zoom Camps take place in a year?',
#   'Can I take the Data-Engineering Zoomcamp for certification more than once a year?',
#   'If I miss the live cohort, can I still join the Data-Engineering Zoomcamp?',
#   'What are the dates for the MLOps Zoomcamp?',
#   "Can I take the Zoomcamps at my own pace if I don't need a certificate?"],
#  '93e2c8ed': ['Is Mage AI being used in the 2024 cohort?',
#   'Were the terraform videos re-recorded for the 2024 edition?',
#   'Was Prefect used for the 2023 cohort?',
#   'Will Prefect be used in the 2024 edition?',
#   'Will Airflow be part of the 2023 cohort?'],
#  'a482086d': ['Can I access the course materials after the course ends?',
#   'Is it possible to review homework after the course finishes?',
#   'Can I work on the final capstone project once the course is over?',
#   'Is it acceptable to follow the course at my own pace after it finishes?',
#   'Can I prepare for the next cohort after the course concludes?'],
#  'eb56ae98': ["Can I still ask questions in the Slack channel if I'm taking the course in self-paced mode?",
#   'Is there support available for self-paced learners in the course?',
#   'What should I do before posting a question in the Slack channel?',
#   'Can I rely entirely on the responses from @ZoomcampQABot?',
#   'Where can I get help if taking the course self-paced?'],
#  '4292531b': ['Which playlist on YouTube contains all the main videos for the course?',
#   'Where can I find additional videos for a specific year?',
#   'Apart from YouTube, where else can I find links to the course videos?',
#   'Are office hours videos included in the main playlist?',
#   'Where is the main YouTube playlist linked in the Slack channel?'],
#  'ea739c65': ['How much time should I allocate per week for this course?',
#   'What is the expected weekly time commitment for this course?',
#   'How many hours per week does this course typically require?',
#   'On average, how many hours do students spend weekly on this course?',
#   'What is the weekly workload for someone taking this course?'],
#  'cb257ee5': ['Can I obtain a certificate if I complete the course at my own pace?',
#   'Is it possible to receive a certificate for a self-paced course?',
#   "Why can't I get a certificate if I finish the course on my own?",
#   'Do I need to join a live cohort for a certificate?',
#   'What is the reason behind not awarding certificates for self-paced courses?'],
#  '04aa4897': ['How can students access the stream for the Office Hour sessions?',
#   'Where will the video URL for the workshop sessions be posted?',
#   'How should students submit their questions during the Office Hour sessions?',
#   "Why shouldn't students post questions in the chat during live streams?",
#   'Where can students find the announcements for the live sessions?'],
#  '9681be3b': ["Will there be recordings of office hours if I can't attend live?",
#   'Can I watch the workshop recordings after the session?',
#   'Are the office hours sessions available for later viewing?',
#   'If I miss the live office hours, can I still access the recording?',
#   'Is it possible to rewatch the office hours at a later time?'],
#  'a1daf537': ['Where can I find the deadlines for homework and projects?',
#   'How can I stay updated about any changes or extensions to deadlines?',
#   'Where should I look to see if there’s an extension on a deadline?',
#   'How do I know if the instructor has updated the deadline?',
#   'Who announces news about deadlines and extensions?'],
#  'be5bfee4': ['Are late homework submissions allowed?',
#   'If the due date has passed, can I still submit Homework?',
#   'Is it possible to submit homework after the deadline if the form is open?',
#   'What should I check to confirm my homework submission after the due date?',
#   'Can homework be submitted late if the course page form is open?'],
#  '0e424a44': ['Where should I upload my homework?',
#   'What location should I use for my homework URL?',
#   'Which platforms are acceptable for hosting my code?',
#   'Can I use any repository for submitting my homework?',
#   'What defines a valid homework URL?'],
#  '29865466': ['How are homework submissions graded in the course management platform?',
#   'Where can I see the points I have earned in the homework?',
#   'What categories are included in the leaderboard for total points?',
#   'How many points do I get for submitting a question to the FAQ?',
#   'How many points do I earn for each Learning in Public link I submit?'],
#  '016d46a1': ['How can I find my random name on the leaderboard?',
#   'Where can I see and change my display name for the course leaderboard?',
#   'How do I find out which random name I was assigned upon account setup?',
#   'How do I access my display name in the Data Engineering Zoom Camp 2024?',
#   'What steps do I follow to locate and modify my leaderboard display name?'],
#  '47972cb1': ['Is Python 3.9 recommended for use in 2024?',
#   'Can I use Python 3.10 for the course?',
#   'Are there any issues with using Python 3.11?',
#   'Why is Python 3.9 still recommended?',
#   'Should I expect stability using Python 3.10 or 3.11?'],
#  'ddf6c1b3': ['Should I use my local machine, GCP, or GitHub Codespaces for my environment?',
#   'What challenges might I face if I set up the environment on my local machine, especially as a Windows user?',
#   'Can I use Docker if I prefer to set up my environment locally?',
#   'How do I start setting up a virtual machine if I prefer that option?',
#   'Why would someone choose to use a virtual machine for this course environment?'],
#  'ac25d3af': ['Does GitHub Codespaces provide pre-installed Docker and Python tools?',
#   'Can I use GitHub Codespaces to open any GitHub repository?',
#   'Is GitHub Codespaces a suitable alternative to CLI/Git Bash for data ingestion?',
#   'What resources does GitHub Codespaces offer?',
#   'Can GitHub Codespaces be used to create a Docker file?'],
#  '251218fc': ['Do I have to use GitHub codespaces for the course?',
#   'Can I complete the course using my laptop instead of GCP VM?',
#   'Is it mandatory to use the suggested platform for this course?',
#   'Are there alternatives to Docker and PostgreSQL provided in the course?',
#   'Can I use my existing tools and setup for the course?'],
#  '3c0114ce': ['Do I need both GitHub Codespaces and GCP for the course?',
#   'Which platform should I choose for the end project?',
#   'Is it better to use BigQuery or set up a local environment?',
#   'Can I use just one platform for the entire course?',
#   'Why might learning BigQuery be advantageous for this course?'],
#  'f43f5fe7': ['What shortcut keys can I use to open the Run command window on a Windows machine?',
#   'What should I type in the Run command window to open the Registry Editor?',
#   'Which registry value should be changed in the Registry Editor when connecting to a GCP VM using VSCode?',
#   'What is the path to the known_hosts file in Windows?',
#   'How can I delete the fingerprint saved within the known_hosts file on a Windows machine?'],
#  'd061525d': ['Why are we using GCP instead of other cloud providers for this course?',
#   "Can I use AWS or Azure if I'm more familiar with those platforms instead of GCP?",
#   'Why is GCP chosen for this course, especially concerning account accessibility?',
#   'What are some advantages provided by GCP for new users?',
#   'Do I need a valid credit card to sign up for a free GCP account?'],
#  '1cd01b2c': ['Do I need to pay for cloud services?',
#   'Are cloud services included in the course fees?',
#   'Can I access cloud services for free?',
#   'Will there be any cost for using GCP?',
#   'Is there a free trial for cloud services?'],
#  'e4a7c3b0': ['Is it possible to complete the course without using any cloud providers?',
#   'Can you run the necessary tools locally instead of using GCP?',
#   'Are there local alternatives for all the materials used in the course?',
#   'Will BigQuery be a problem if GCP is unavailable?',
#   'Is there a guide available for setting up a home lab for this course?'],
#  '7cd1912e': ['Can I use AWS for this course instead of GCP?',
#   'What should I remember if I choose to use AWS for the course?',
#   'How will my final capstone be evaluated if I use AWS?',
#   'Will I have difficulties getting help if I use AWS instead of GCP?',
#   'If I want to use a different tool than the ones suggested, is that possible?'],
#  '52393fb3': ['When will additional live Zoom calls besides office hours be scheduled?',
#   'Are there any live Q&A sessions planned during the Capstone period?',
#   'Will announcements be made beforehand about extra Zoom calls?',
#   'Can we expect any live calls to address Capstone project questions?',
#   'How will we be informed about potential extra Zoom calls?'],
#  '10515af5': ['Are we using the NYC Trip data for January 2021 in our project?',
#   'Is the NYC Trip data from January 2022 being used for the project?',
#   'Has the project data source changed from last year?',
#   'Where can I find the NYC Trip data for the project?',
#   'Will the NYC Trip data remain the same as last year?'],
#  'cdb86a97': ['Is the 2022 repository still accessible?',
#   'Where can I find the 2022 course materials?',
#   'Has the 2022 repository been relocated?',
#   'Can I still access the 2022 stuff?',
#   'Is there a new location for the 2022 repo?'],
#  '3e0114ad': ['Can I select a tool of my choice for my final project?',
#   'Is it allowed to use any tool for completing my project?',
#   'Am I permitted to use Airflow for my final project?',
#   'Are there restrictions on which tools can be used for the project?',
#   'Can any tool be utilized for my project submission?'],
#  'b2799574': ['Can I use a different tool instead of the tools you use in the course?',
#   'Is it allowed to use Airflow or Prefect instead of Mage?',
#   'Can I utilize AWS or Snowflake instead of GCP products?',
#   'Am I able to choose Tableau instead of Metabase or Google Data Studio?',
#   'If I pick a different tool, what should I consider for the capstone project?'],
#  '2f19301f': ['How can I contribute to the course?',
#   'What should I do if I find the repository useful?',
#   'How do I improve the text or structure of the repository?',
#   "What does it mean to 'star the repo'?",
#   'Can I share the course material with friends?'],
#  '7c700adb': ['Is the course compatible with Windows, Mac, and Linux?',
#   'Can I use Linux for this course?',
#   'Do students typically use Windows for this course?',
#   'Are Mac users able to successfully complete the course?',
#   'What operating systems are supported in this course?'],
#  '44b14808': ['How do Windows users handle shell scripts in later modules?',
#   'What workaround exists for using *.sh files on Windows?',
#   'Why is WSL environment setup recommended for this course?',
#   'Can git bash or MINGW64 be used for shell scripts in this course?',
#   'What modules involve shell scripts that are problematic for Windows users?'],
#  '76e4baf6': ['What books and additional resources do you recommend for the course?',
#   'Is there a list of recommended books?',
#   'Where can I find more resources?',
#   'Are extra resources available for the course?',
#   'Do you suggest any further reading material?'],
#  '48b533a8': ['What happens if I miss the first project deadline?',
#   'Can I resubmit my project if I fail the first attempt?',
#   "Is there a second project submission opportunity if I'm late?",
#   'How many chances do I have to complete the project successfully?',
#   'What are Project Attempt #1 and Project Attempt #2?'],
#  '954044d1': ['What should I do first when troubleshooting an issue in the course?',
#   'How should I search for error solutions online?',
#   'Why is it important to describe what I have tried when asking for help?',
#   'What are recommended ways to post and format questions on Slack?',
#   "What should I do if I still can't solve a problem after following all the steps?"],
#  'a820b9b3': ['When should I ask for help if the troubleshooting guide does not resolve my issue?',
#   'What information should I include when I ask a question about my code?',
#   'What details about my coding environment are important when asking for assistance?',
#   "Why is it important to include what I've tried that did not work when asking for help?",
#   'If I get an error with a line number, what should be my first step?'],
#  'f2945cd2': ['How do I set up a GitHub account and clone the course repository?',
#   "What's the process to access instructors' code and make pull requests?",
#   'Where can I find a tutorial on creating my own repositories for notes?',
#   'What should I do to ensure certain files like large databases or passwords are not saved in the repository?',
#   'Can you suggest a resource to learn more about Git and common issues?'],
#  'eb9d376f': ['What should I do if I get a Makefile missing separator error in VS Code?',
#   'How can I fix the Tab using spaces issue in my Makefile?',
#   'What is the solution for a Makefile:2: *** missing separator error?',
#   'Why am I getting a missing separator error in Makefile?',
#   'How do I convert spaces to tabs in VS Code for my Makefile?'],
#  '72f25f6d': ['How can I open an HTML file from Linux on WSL in a Windows browser?',
#   'What command should be used to open a webpage with wslview?',
#   'How do I customise which browser wslview uses?',
#   'What package needs to be installed to open HTML files with a Windows browser from WSL?',
#   'Can I specify a different browser for wslview by setting an environment variable?'],
#  'a1e59afc': ['How do I set up Chrome Remote Desktop on a Debian Linux VM in Compute Engine?',
#   "What command should I use to unzip the 'gz' file after downloading Yellow Taxi Trip Records data?",
#   'What is the alternative link for downloading the 2021 Yellow Taxi Trip Records data due to the error on TLC website?',
#   'What error might I encounter when trying to download 2021 taxi data from the TLC website?',
#   'Which tool allows remote access to graphical applications on a Compute Engine Debian VM?'],
#  '71c10610': ['Why won’t the taxi data file store correctly if it has a csv.gz extension instead of csv?',
#   'What is an alternative to storing the taxi data file as output.csv?',
#   'How can I derive the file name from the taxi data URL?',
#   'Why should I use the pandas read_csv function for files with a csv.gz extension?',
#   'What changes need to be made to the csv_name variable to correctly handle the taxi data file?'],
#  '17a5aea1': ['Where can I find the data dictionary for Yellow Taxi trips in NYC?',
#   'Can you give me the link to the data dictionary for Green Taxi trips?',
#   'What is the URL for the NYC Yellow Taxi data dictionary?',
#   'How do I access the Green Taxi trip records data dictionary?',
#   'Is there a specific link for Yellow Taxi trip data details in NYC?'],
#  '5a275db7': ['How can I unzip a downloaded parquet file in the command line as mentioned in Module 1?',
#   'What steps should I follow to import an unzipped csv file using pandas?',
#   'In the ingest_data.py script, where should I add the line defining the parquet file name?',
#   'How do I edit the code to download files directly as parquet in ingest_data.py?',
#   'What is the process to convert a .parquet file to .csv and ensure it aligns with the rest of the script?'],
#  '7ec0f9b0': ['How do I install wget on Ubuntu?',
#   'What is the easiest way to install wget on MacOS?',
#   'How can I install wget on Windows?',
#   'Can I use a Python library to replace wget?',
#   'What is an alternative method to download a file without using wget?'],
#  'bb1ba786': ['What should I add before the wget command when running it in a Jupyter Notebook?',
#   'How do I use the Python wget module installed with pip to download a file?',
#   'What flag can I add to the wget command to bypass certificate verification issues?',
#   'Should I add a specific character before the wget command if running in CLI?',
#   "Is there a way to run wget without verifying the website's certificate?"],
#  '2f83dbe7': ['How can I use a backslash as an escape character in Git Bash for Windows?',
#   'What command allows backslash to be used as an escape character in Git Bash for Windows?',
#   'Is it necessary to include the backslash escape character setting in the .bashrc file for Git Bash in Windows?',
#   'Can you confirm the command to type in the terminal to set backslash as an escape character in Git Bash for Windows?',
#   "What's the specific command Alexey uses to set the backslash as an escape character in Git Bash on Windows?"],
#  '543ff080': ['How can I manage account-specific secrets for GitHub Codespaces?',
#   'Where can I find the instructions to store secrets for GitHub Codespaces?',
#   'What documentation provides information on storing secrets in Codespaces?',
#   'What steps should I follow to store secrets in GitHub Codespaces?',
#   'Which GitHub feature is used to handle secrets for Codespaces?'],
#  'd407d65b': ['How do I fix the issue of not being able to connect to Docker daemon at unix:///var/run/docker.sock?',
#   'What should I do if the Docker daemon is not running?',
#   'What command can I use to update WSL in PowerShell?',
#   'How can I ensure the Docker daemon starts properly?',
#   'What is the solution for Docker connection issues related to the daemon?'],
#  'c9375c56': ['What should Windows 10 Pro users do if they want to use Hyper-V with Docker?',
#   'What is the alternative for Docker on Windows Home if Hyper-V is not available?',
#   'Where can I find instructions to enable Hyper-V on Windows 11?',
#   'What link provides detailed steps for installing WSL on Windows 11?',
#   'How can I resolve the WslRegisterDistribution error: 0x800701bc when installing WSL2?'],
#  'e866156b': ["What happens if I encounter a message saying 'repository does not exist or may require docker login' when trying to pull a Docker image?",
#   'Do I need to perform a docker login to fetch the Docker images used in the Data Engineering Zoomcamp?',
#   "How can I resolve the error 'permission denied' when creating a PostgreSQL Docker container for the New York Taxi Database on macOS M1?",
#   "Why does the command 'docker pull dbpage/pgadmin4' fail with an error about repository access?",
#   "What is a possible solution if I get a 'permission denied' error while mounting a volume on macOS M1 when using Rancher Desktop?"],
#  '16370470': ["What should I do if I can't delete a local folder mounted to a Docker volume?",
#   "Why can't I delete a folder created by a Docker container using the regular delete method?",
#   'How can I forcefully delete a protected folder created by a Docker container?',
#   'What are the command options for deleting a folder with read and write protection?',
#   "What command can I use if my application can't start due to an access error with a Docker-mounted folder?"],
#  '316df755': ["What should I do if Docker won't start or is stuck on settings in Windows 10?",
#   'How can I switch Docker containers from Windows to Linux or vice versa?',
#   'What must be enabled to use Hyper-V as the backend for Docker on Windows 10 Pro?',
#   'Where can I find a tutorial to enable Hyper-V on Windows 11?',
#   'Can I use WSL2 with Docker on Windows 10, and where can I find the steps to do it?'],
#  'f3aa9252': ['Should I run docker commands from the Windows file system or a Linux distribution in WSL?',
#   'Can I use Docker with Windows 10/11 Home Edition?',
#   'What should I do if Docker remains stuck after setting up WSL2 or Hyper-V?',
#   'How can I reset Docker if it is not working correctly?',
#   'Is there a tutorial available for setting up Docker with WSL2?'],
#  'a4abe7a5': ['How do I achieve optimal file system performance with Docker on Windows 10 Home?',
#   'Which Linux distro should I use to store code for Docker on WSL2?',
#   'Where can I find more information on Docker best practices?',
#   'What backend does Docker use by default on Windows 10 Home?',
#   'Is there special advice for Windows 11 Home users regarding Docker?'],
#  'fb930700': ["What should I do if I encounter the 'the input device is not a TTY' error while running Docker on Windows?",
#   'How can I solve the issue where Docker run command fails due to TTY input on mintty?',
#   "How do I use winpty to fix Docker's input device error on Windows?",
#   'Can I create an alias to always prefix Docker commands with winpty?',
#   'Where should I add the alias for Docker commands to automatically include winpty on Windows?'],
#  'aa187680': ['What error might I encounter when trying to pip install on a Docker container in Windows?',
#   'What is the error message indicating a temporary failure in name resolution when pip installing on Docker?',
#   'How can I solve the connection error when trying to pip install on a Docker container?',
#   'What is the suggested solution for fixing the pip install connection issue on a Docker container?',
#   'Which DNS server can be used in the Docker run command to solve the pip install issue?'],
#  'b000e899': ['What should I do if the Docker ny_taxi_postgres_data folder is empty even after running the script?',
#   'How can I resolve the issue of an empty ny_taxi_postgres_data folder in VS Code on Windows?',
#   'Which command should I use to fix the empty ny_taxi_postgres_data folder issue on Windows?',
#   'Why is my Docker ny_taxi_postgres_data folder not showing files in VS Code?',
#   'What parameter should be quoted in the Docker command to make ny_taxi_postgres_data folder contents visible in VS Code?'],
#  '9c66759f': ['How do I set up Docker on macOS?',
#   "Is the method in the 'Setting up docker in macOS' article up-to-date?",
#   "Have there been issues with Docker's licensing model affecting setup?",
#   'What is the recommended way to install Docker on Mac now?',
#   'Can you direct me to a reliable method for downloading Docker on macOS?'],
#  'e3106e07': {'questions': ["How can I resolve the error 'could not change permissions of directory /var/lib/postgresql/data: Operation not permitted' when running a Docker command?",
#    'What steps should I follow to create a local Docker volume for Postgres data?',
#    'How do I verify that the Docker volume dtc_postgres_volume_local has been created successfully?',
#    'What is an alternate error I might encounter when initializing a Postgres database in Docker?',
#    'What alternative configurations can cause the folder ny_taxi_postgres_data to be empty?']},
#  '72229da5': ["How can I fix the 'invalid reference format' error when mapping volumes on Windows with Docker?",
#   "What should I do if the mapping method shown in the course video doesn't work for me on Windows?",
#   "Why is my folder 'ny_taxi_postgres_data;C' being created automatically when I try volume mapping in Docker?",
#   "Can I use a volume name instead of a path to avoid the 'invalid reference format' issue in Docker on Windows?",
#   "What is the correct way to map volumes in Docker for Mac when using the '$(pwd)' command?"],
#  '58c9f99f': ["How can I fix the 'invalid mode' error in Docker related to the PostgreSQL data path?",
#   'What is the correct way to change the mounting path in Docker for PostgreSQL data?',
#   'What should I replace the invalid mounting path with in Docker for PostgreSQL?',
#   "Which options do I have for the mounting path to avoid the 'invalid mode' error in Docker?",
#   'What are the correct mounting path formats for PostgreSQL data in Docker to prevent errors?'],
#  'bc42139a': ["What does the error 'Error response from daemon: error while creating buildmount source path' mean in Docker?",
#   'What should I avoid doing on the second run of the Docker command for PostgreSQL?',
#   'How should I run the Docker command the second time to avoid the file exists error?',
#   'What is the significance of -v <your path>:/var/lib/postgresql/data in the Docker command?',
#   'What environment variables are set in the Docker command for PostgreSQL in Module 1?'],
#  'a146e3ee': ['What should I do if I encounter a Docker build error mentioning error checking context?',
#   "Why does the Docker build error say 'can't stat /home/user/repos/data-engineering/week_1_basics_n_setup/2_docker_sql/ny_taxi_postgres_data'?",
#   'How can I resolve the permission issue when running a Docker build on Ubuntu?',
#   'Which files are necessary to avoid the build error in Docker for module 1?',
#   'Where can I find more detailed information about fixing the Docker build context error?'],
#  '593a85ba': ["What should I do if I get 'ERRO[0000] error waiting for container: context canceled' after installing Docker?",
#   'How can I verify if Docker was installed via snap?',
#   'What does the error \'error: unknown command "status", see \'snap help\'\' indicate when checking Docker?',
#   'What is a possible solution if the bind for 0.0.0.0:5432 fails in Docker?',
#   "If I encounter 'context canceled' error, should I reinstall Docker?"],
#  '50bd1a71': ["Why am I getting a Docker build error related to 'can’t stat /home/fhrzn/Projects/…./ny_taxi_postgres_data'?",
#   'What is causing the folder to appear empty during a Docker build on PopOS Linux?',
#   'How can I resolve the authorization rights issue for a host folder in Docker on PopOS?',
#   'What command should I use to add permission for everyone to a folder for Docker?',
#   "Can you give an example command to add permissions to the 'ny_taxi_postgres_data' folder?"],
#  'f409f751': ['What should I do if I get a permission denied error while rebuilding a Docker container on Ubuntu/Linux?',
#   "Why am I seeing a 'failed to read dockerfile' error when trying to rebuild my Docker container?",
#   'How can I fix the permission denied issue when running the Docker build command for a second time?',
#   'What command should I use to grant permissions to the folder created for Docker files?',
#   "Is there an alternative permission setting if 'sudo chmod -R 755' doesn't resolve the error?"],
#  '7d217da3': ['What command can I use to obtain the Docker network name?',
#   'How do I list Docker networks?',
#   'Where can I find the name of a Docker network?',
#   'Is there a way to view Docker networks?',
#   'Which command shows the Docker network names?'],
#  '09081824': ["What should I do if I get a conflict error when trying to start a Docker container with the name 'pg-database'?",
#   'How can I resolve the error message that says a Docker container name is already in use?',
#   "Which command should I use to stop a running Docker container named 'pg-database'?",
#   "What command do I use to remove a Docker container with the name 'pg-database'?",
#   "How can I restart a Docker image without removing the container if it's already using the network name 'pg-database'?"],
#  '4df80c55': ['What should I do if I encounter a sqlalchemy.exc.OperationalError when using docker-compose?',
#   "How do I solve the issue when Docker cannot translate the host name 'pgdatabase'?",
#   "What does the error 'could not translate host name pgdatabase to address' mean in Docker?",
#   'How can I identify the correct network for my ingestion script when using docker-compose?',
#   'What changes must I make to the default names like pg-network and pgdatabase in my Docker setup?'],
#  '3aee7261': ['How can I install Docker on a MacOS VM running on Linux?',
#   'Can I install Docker on a Windows 11 VM with a Linux host?',
#   'What should I do to enable Docker on an Intel CPU VM?',
#   'What are the steps to install Docker on an AMD CPU VM?',
#   "Why can't I install Docker on my VM due to nested virtualization?"],
#  '6497b659': ['How do I manage Docker containers, images, and networks from VS Code?',
#   'What should I install to manage Docker from VS Code?',
#   'What icon should I use to launch Docker management in VS Code?',
#   'Can VS Code connect with Docker running on WSL2?',
#   'Which command is used to stop a Docker container?'],
#  'a02f2039': ['What should I do if my PostgreSQL Docker container logs say the database system is shut down?',
#   'How can I resolve the issue when my PostgreSQL Docker container is not accepting requests?',
#   'Why does my attempt to connect to PostgreSQL in a Docker container result in a server closed the connection unexpectedly error?',
#   'What does it mean when the PostgreSQL server terminated abnormally before processing the request in Docker?',
#   'What steps should I take when my PostgreSQL database directory appears to contain a database and the system is shut down?'],
#  'c6db65aa': ['How can I install Docker on some versions of Ubuntu?',
#   'Which command do I use to install Docker with snap?',
#   'Is there an issue installing Docker on certain Ubuntu versions?',
#   "What's an alternative method to install Docker on Ubuntu?",
#   'How do I use snap to get Docker on my system?'],
#  'f476a606': ['How can I resolve the mounting error when using Docker-Compose?',
#   'Why is my Docker named volume not being properly recognized by the compose file?',
#   'What should I do if Docker creates a new mounting directory instead of using the existing one?',
#   'How can I inspect the location of my Docker volume?',
#   'Is there a renaming solution for fixing Docker-Compose mounting issues?'],
#  'e41b100c': ['How do I ensure that my Postgres database is running before translating the host name to address?',
#   'What command should I use to start the Docker containers in detached mode?',
#   'How can I check the status of my running containers?',
#   'What command is used to view the logs for a specific container?',
#   "What should I do if 'docker ps' does not show 'pgdatabase' as running?"],
#  'cd0f9300': ['Why is Docker Compose creating its own default network?',
#   'How do I find the new network name created by Docker Compose?',
#   'What should I do if I lose database data after running `docker-compose up`?',
#   "How can I resolve the error 'Name or service not known' for 'pg-database'?",
#   'Is there an alternative tool to pgcli for database operations if problems persist?'],
#  '7f845a1c': ["What error do you get when Docker-Compose can't resolve a hostname?",
#   'How can I list all stopped and running containers in Docker?',
#   'What should I do if Docker-Compose fails to connect to the server on localhost:8080?',
#   'How should I modify the hostname to avoid resolution issues in Docker-Compose?',
#   'How do I specify the same network in both containers in a docker-compose.yml file?'],
#  '36e54439': ['How can I ensure PGAdmin docker contents persist on GCP when using docker-compose?',
#   'What is a common issue when running docker-compose with Postgres on GCP?',
#   'What change should be made to the docker-compose file to make PGAdmin data persist on GCP?',
#   "Why might the volume specification './pgadmin:/var/lib/pgadmin:wr' not work on GCP?",
#   "How should the volumes section look in docker-compose to persist PGAdmin's data on GCP?"],
#  '32e8450c': ['What should I do if my Docker engine keeps crashing continuously?',
#   "Why am I seeing 'failed to fetch extensions' error messages on my screen?",
#   'Is there a way to stop Docker from crashing after a restart?',
#   'How can I resolve the issue where Docker is not working despite restarting?',
#   "What are the steps if updating Docker doesn't solve the crashing problem?"],
#  '96606db2': ['How do we persist pgAdmin configuration in the Docker-Compose file?',
#   'What are the necessary environment variables for setting up pgAdmin in Docker?',
#   'Which folder on the host machine corresponds to pgAdmin session settings in the container?',
#   'What command should be executed before running docker-compose up to grant pgAdmin container access to the mounted volume?',
#   'What username and user group does the pgAdmin container run with?'],
#  '0882bfac': ["What should I do if I get a 'permission denied' error when using Docker-Compose?",
#   'How can I stop pgAdmin from forgetting my database connection each time I restart the containers?',
#   "What steps do I need to follow to resolve the 'permission denied' error in Docker?",
#   'Where should I add the volume configuration in my docker-compose.yaml for pgAdmin?',
#   'How do I create a Docker group and add my user to it to avoid permission issues?'],
#  '7d067f5c': ['Why is docker-compose not available after updating .bashrc?',
#   'What should I do if docker-compose-linux-x86_64 is downloaded instead of docker-compose?',
#   'How can I fix docker-compose command issues after following the 1.4.1 video?',
#   'What steps are needed to ensure docker-compose works in Google Cloud VM?',
#   'Why do I need to rename docker-compose-linux-x86_64 to docker-compose?'],
#  'ff352621': ["How do I resolve the Docker-Compose error related to credentials when running 'docker-compose up -d'?",
#   'What command can I use to install the tool to fix the Docker-Compose credentials issue?',
#   'Where can I find more information about the error related to Docker-Compose and getting credentials?',
#   'Which module covers solutions for Docker-Compose issues related to credentials?',
#   'What is the specific issue number in the GitHub repository for the Docker-Compose credentials problem?'],
#  '2d653208': ['What should I do if I encounter errors with Docker compose and pgadmin setup?',
#   'How can I create a new volume on Docker for my setup?',
#   'What steps must I follow for the order of execution when using Docker and pgadmin?',
#   'Which settings should I use to set up the pgadmin server after opening it?',
#   'What changes should I make in the docker-compose.yml file to avoid issues?'],
#  'f09ea61e': ["How can I solve the 'docker-credential-desktop' executable file not found error when using Docker Compose?",
#   'Where can I find the config.json file for Docker on my system?',
#   'What modification should be made to the config.json file to fix the Docker Compose up error regarding credentials?',
#   'What is the correct value to use instead of credsStore in the docker config.json file?',
#   'What steps should I follow after editing the Docker config.json file to resolve the credential error?'],
#  'fbd3d2bb': ['Which docker-compose binary should I use for WSL?',
#   'Where can I download the docker-compose binary for WSL?',
#   'What commands should I run to check my system type for docker-compose?',
#   'How can I use uname to find the right docker-compose binary?',
#   'Is there a single command to download docker-compose for WSL?'],
#  '0b014d0c': ['Why does my Docker-Compose file give an undefined volume error in Windows/WSL?',
#   "How can I fix the undefined volume error for 'pgdatabase' in my docker-compose.yaml file?",
#   'What should I do if my docker-compose.yaml file has an invalid compose project error?',
#   'How do I include a volume in my docker-compose.yaml file to fix an error?',
#   "Where should the 'volumes' section be placed in my docker-compose.yaml file?"],
#  'd21bff1d': ['What causes the WSL Docker directory permissions error?',
#   'How can I resolve the directory permissions error on WSL?',
#   'Why should I use Docker volumes instead of the local drive?',
#   "Is the 'user:' directive necessary when using Docker volumes?",
#   'What benefits do Docker volumes provide in managing permissions?'],
#  '6afb7b55': ['Why does pgadmin sometimes not work when querying Postgres on Windows?',
#   'What libraries are required if pgadmin fails on Windows?',
#   'What is the solution if pgadmin does not work in Windows for Postgres?',
#   'What can I use as an alternative to pgadmin for querying Postgres?',
#   'How can I install the required library for Postgres querying if pgadmin fails?'],
#  'b51c3b82': ["What causes the 'Insufficient system resources' error in WSL?",
#   'How can I update Windows Terminal to fix the WSL error?',
#   'Where do I find the library of apps installed along with Windows Terminal in Microsoft Store?',
#   'What should I do after updating Windows Terminal to resolve the system resources issue?',
#   'How can I ensure my Windows security updates are up to date to address WSL issues?'],
#  '326af690': ['What should I do if my WSL integration with Ubuntu stops with exit code 1?',
#   'How can I fix the DNS issue causing WSL to stop unexpectedly?',
#   'What steps should I follow to switch Docker to Linux containers?',
#   "Why might I receive 'bash: conda: command not found' error?",
#   'What should I do if my database is uninitialized and the superuser password is not specified?'],
#  'c2ec9047': ['How can I fix the permissions issue when using SSH through WSL2 on Windows?',
#   'What steps should I take to change the permissions for the private key SSH file in WSL2?',
#   "If using sudo before the SSH command doesn't work, what other solutions can I try?",
#   'Where should I look for .ssh keys when using WSL2?',
#   'How do I copy the content of the .ssh folder from Windows to WSL2?'],
#  '3b711e73': ['How can I resolve the issue of WSL2 not referencing the correct .ssh/config path from Windows?',
#   'Where should I create the config file if WSL2 is not recognizing the correct .ssh/config path?',
#   'What should I do if WSL2 could not resolve the host name?',
#   'How do I set up a new .ssh/config file in WSL2?',
#   'What information do I need to include in the config file to resolve the host name issue in WSL2?'],
#  'cfe07c9d': ["How can I resolve the 'connection failed' error in PGCLI when the port 5432 fails?",
#   "What should I do if PGCLI cannot receive data from the server and shows 'Connection refused'?",
#   "How can I fix the 'could not send SSL negotiation packet' error in PGCLI for port 5432?",
#   'What is the correct PGCLI command to connect to a local database on port 5432?',
#   'Which command should I use to connect to a local PostgreSQL database using PGCLI?'],
#  'acf42bb8': ['What might cause a PGCLI --help error in Module 1?',
#   'How can I troubleshoot an installation issue with PGCLI?',
#   'Where should I look for answers about PGCLI installation problems?',
#   'Why am I encountering an error when running PGCLI --help?',
#   'What should I do if sy fails for PGCLI in Module 1?'],
#  '176ce516': ['Can we run pgcli inside another Docker container?',
#   'Do we need to run pgcli in another container for this course?',
#   'Is it necessary to execute pgcli within a separate Docker container?',
#   'Should pgcli be run inside a different container for accessing the database?',
#   'Can pgcli be used directly from our computer without another container?'],
#  '3e5d1e9b': ["Why am I getting a password authentication failed error for user 'root' in PGCLI?",
#   'What should I do if I already have Postgres installed locally and get a password error in PGCLI?',
#   'Which port should I use to mitigate password authentication issues with Docker Postgres?',
#   'How do I connect to a Docker Postgres container using pgcli with a different port?',
#   'Where can I find a visual explanation for port mapping and networks in Docker?'],
#  '78833f32': ['How can I resolve PermissionError: [Errno 13] Permission denied when using pgcli?',
#   "What steps should I take if I see 'Permission denied' error for '/Users/vray/.config/pgcli'?",
#   'What is the recommended way to install pgcli without using sudo?',
#   'How can I prevent my system python from being affected when installing pgcli?',
#   "What should I do if conda install gets stuck at 'Solving environment'?"],
#  '63823f21': ["What error message is displayed for 'no pq wrapper available'?",
#   "What Python version should be used to avoid 'psycopg2-binary' installation failures?",
#   'How can I check my current Python version?',
#   "What command should I use to install 'psycopg2_binary'?",
#   'How should pgcli be installed?'],
#  'b36ea564': ['What should I do if my Bash prompt is stuck on the password command for postgres in PGCLI?',
#   "How do I resolve the PGCLI connection failure with the error 'FATAL: password authentication failed for user root'?",
#   'What should I do if I continually face a password authentication failed error despite entering the correct password?',
#   'Can you provide alternative terminals to use if PGCLI is stuck on the password prompt on Windows?',
#   'What steps should I follow if I closed the connection to the Postgres:13 image and now face authentication issues?'],
#  'e2a46ce5': ["What should I do if I have installed pgcli but still get 'command not found' in Git Bash?",
#   "How can I fix the 'pgcli: The term pgcli is not recognized' error in Windows Terminal?",
#   'What steps should I follow to add the Python path to Windows PATH for pgcli?',
#   'Where can I find the Scripts directory if I have Python installed under c:\\python310\\lib\\site-packages?',
#   'What reference can I consult for more information on adding pgcli to Windows PATH?'],
#  '27bdbc3f': ["How can I run pgcli in a Docker container if I don't want to install it locally?",
#   'What Docker command should I use to run pgcli with the course-specific configuration?',
#   'What network name should I use for running pgcli in the Docker container according to the course?',
#   'What hostname, username, port, and database name do I need to set for running pgcli in the container?',
#   'What is the URL for the pgcli home page mentioned in the course materials?'],
#  'f7c5d8da': ['Why do we use quotations around columns with capital letters in PGCLI?',
#   'Is PULocationID recognized without using quotations in PGCLI?',
#   'How are unquoted local identifiers treated in PGCLI?',
#   "What happens if I don't use quotations for columns with capital letters in PGCLI?",
#   'Where can I find more information on case sensitivity in PGCLI?'],
#  'c91ad8f2': ['What should I do when I encounter the error column c.relhasoids does not exist while using the command \\d <database name>?',
#   'How can I resolve the issue of the error column c.relhasoids does not exist?',
#   'What steps are necessary to fix the error column c.relhasoids does not exist using \\d <database name>?',
#   'Why do I get an error column c.relhasoids does not exist and how can I address it?',
#   'What is the solution for the error column c.relhasoids does not exist when using \\d <database name> command?'],
#  '88bf31a0': ["What causes the OperationalError related to password authentication failure for user 'root' in Postgres?",
#   'What steps can I take if I get an OperationalError while uploading data via Jupyter Notebook connection to Postgres?',
#   'Why do I need to substitute port 5432 when using Postgres in Docker?',
#   "What should I do if substituting the port doesn't resolve the Postgres OperationalError?",
#   'How can I check if there is a conflicting Postgres service running on my Windows machine that might cause an OperationalError?'],
#  '23524e6d': ["What should I do if I encounter a Postgres OperationalError stating that the role 'root' does not exist?",
#   'How do I verify if there is a root user capable of logging in when connecting via Docker?',
#   'What could be a possible solution when Postgres is already installed and I face a connection issue on port 5432?',
#   "How do I resolve the 'role root does not exist' error while using Docker Compose?",
#   "What is an alternative solution if changing the port doesn't resolve the Postgres OperationalError?"],
#  '9211bbd6': ["Why is Postgres returning FATAL: database 'ny_taxi' does not exist?",
#   'How can I verify that Postgres is running using Docker?',
#   'What should I do if I have Postgres software installed on my computer?',
#   'Which port can I use if 5432 is already occupied?',
#   "What is the root cause of psycopg2.OperationalError: connection to server at 'localhost' (::1), port 5432?"],
#  '5db86809': ["What should I do if I encounter a ModuleNotFoundError for 'psycopg2' in Module 1?",
#   "How can I resolve the error if the command pip install psycopg2-binary doesn't work?",
#   'Is there a way to update the psycopg2 package if it is already installed?',
#   'What steps should I take if updating psycopg2-binary or pip doesn’t solve the ModuleNotFoundError?',
#   'What might be the issue if I’m getting a pg_config not found error while using psycopg2 on a Mac?'],
#  '20c604dd': ["What could cause a 'Column does not exist' error in join queries on a MacBook Pro M2 using Psycopg2?",
#   "How should column names be enclosed in join queries to avoid the 'Column does not exist' error in Psycopg2?",
#   'Why does mentioning column names directly in join queries cause an error in Psycopg2?',
#   'What could happen if column names are enclosed in single quotes in join queries with Psycopg2?',
#   "What is the solution for the 'Column does not exist' error in Psycopg2 on a MacBook Pro M2?"],
#  'b11b8c15': ["What should I do if the create server dialog in pgAdmin doesn't appear?",
#   "Is there a workaround for the missing create server dialog in pgAdmin's new version?",
#   'Where can I find the server creation option in the latest pgAdmin?',
#   'How do I register a server in the updated pgAdmin?',
#   'Is the create server option moved in the new pgAdmin version?'],
#  'a6475348': ['What should I do if I encounter a blank screen after logging into pgAdmin when using GitHub Codespaces in the browser?',
#   'How do I set the environment variable to solve the CSRF error in pgAdmin running in a Docker container?',
#   "How can I modify the 'docker run' command to address the CSRFError issue with pgAdmin?",
#   'What is an alternative way to avoid the blank screen issue in pgAdmin if using GitHub Codespaces in the browser?',
#   'Why does the blank screen issue not occur when using GitHub Codespaces in the locally installed VSCode?'],
#  '1ea7680e': ['How can I modify the docker run command to access the pgAdmin address on my browser?',
#   'What changes should I make in the docker-compose.yaml configuration to access PgAdmin via the browser?',
#   "What might be the cause if I can't access the pgAdmin address despite switching browsers?",
#   "How can I resolve the ModuleNotFoundError for 'pysqlite2' in Python?",
#   'What should I do if I encounter the ImportError indicating the missing sqlite3.dll in Anaconda?'],
#  '10acd478': ['Why am I missing 100000 records when I rerun the ingestion script in the Jupyter notebook?',
#   'What happens if I follow the video 1.2.2 and rerun the whole script from top to bottom?',
#   'How can I fix the issue of missing records when rerunning the Jupyter notebook script?',
#   'Why is there a call to the iterator before the while loop in the Jupyter notebook script?',
#   'What is the purpose of running the script just as a test in the Jupyter notebook?'],
#  '752e8452': ["How can I preview CSV files in VSCode if they're compressed?",
#   'What tool can unzip gzip files on Ubuntu?',
#   'What might I need to install on Ubuntu to handle gzip files?',
#   'Which Python library is recommended for reading CSV files?',
# ...
#   'What should I do if I am using the repo’s notebook during Module 4?',
#   'Who added the note about the relationship between the video and the notebook?',
#   'What tool does the video eventually use in the notebook?',
#   'Will everything work if I just watch the video and follow along?'],
#  '1db86601': ['How can I pass AWS credentials as environment variables to my Docker container?',
#   'What should be the order of specifying environment variables and the image name in a Docker run command?',
#   'What additional environment variable might I need to pass if I am using AWS STS?',
#   'How can I provide AWS credentials to my Docker container if environment variables are not working?',
#   'What is the Docker run command to map AWS configuration files into the container?'],
#  '047baefe': ['How can I view the contents of the app directory in the docker container?',
#   'What command should I use to build the docker image?',
#   'What is the purpose of the CMD instruction in Dockerfile?',
#   'What do I need to modify in Dockerfile if I want to copy my own files?',
#   'How can I automatically list the contents of the app directory when running the container?'],
#  '4f240372': ["How can I resolve a mismatch between the image's platform and the host platform when building a Docker image in Module 4?",
#   'What is the command to build a Docker image with a specific platform tag to avoid platform mismatch errors?',
#   'What steps should I follow to prevent platform detection warnings when building Docker images in Module 4?',
#   'How do I ensure my Docker image is built for linux/arm64 if my host platform is detected as linux/arm64/v8?',
#   'What tag should I add to my Docker build command to specify the platform and avoid mismatch issues?'],
#  '7aef625b': ['What should I do when I get a 403 Forbidden error with the apply_model() function in score.ipynb?',
#   "What is the alternative URL to use for input_file when I encounter an HTTP Error 403 in Module 4's apply_model()?",
#   'How can I resolve the HTTP Error 403 when running apply_model() in the score.ipynb notebook?',
#   'What is the correct input_file URL to use to avoid a 403 Forbidden error in Module 4: Deployment?',
#   'Who can I contact for more help with the HTTP Error 403 issue in apply_model() from score.ipynb?'],
#  'a3aa3a7d': ["How do I resolve ModuleNotFoundError for 'pipenv.patched.pip._vendor.urllib3.response'?",
#   "What steps should I take if I get an error in 'pipenv.patched.pip._vendor.urllib3.connectionpool.py'?",
#   "What can I do if I encounter issues with 'pipenv.patched.pip._vendor.urllib3.response'?",
#   "How can I fix an error related to 'pipenv.patched.pip._vendor.urllib3.response'?",
#   'What command should I use to resolve a ModuleNotFoundError in pipenv?'],
#  'd2719204': ['Why do I get a login window in Grafana after running docker-compose up?',
#   'What credentials should I use when I see a login prompt in Grafana?',
#   'How do I access Grafana on my local machine?',
#   'What is the default password for Grafana after setting it up?',
#   'Where can I find additional help for logging into Grafana?'],
#  '30b8e8e6': ["What should we do if docker compose up --build shows 'unknown flag' error in Linux?",
#   "Why do we get an 'unknown flag: --build' message when starting services as demonstrated in video 5.2?",
#   'How is docker-compose run differently in Linux to start monitoring services?',
#   'What is the correct command to use for starting services with docker-compose in Linux as mentioned by Ashish Lalchandani?',
#   'In which module and video can we find instructions for starting monitoring services using docker-compose?'],
#  'f33fc6e9': ['What should I do when I encounter a KeyError for ‘content-length’ while running prepare.py in Module 5?',
#   'How can I resolve the issue of a KeyError from content-length in prepare.py?',
#   'Is there a fix for the KeyError ‘content-length’ error when executing prepare.py?',
#   "Can you suggest a solution for the KeyError regarding 'content-length' in prepare.py?",
#   "What steps should I take to address the KeyError ‘content-length’ in Module 5's prepare.py?"],
#  'd828de2a': ["When I run the command 'docker-compose up –build' and get 'Max retries exceeded with url: /api', what might be the problem?",
#   'Why does the evidently service exit with code 2 when I run my setup?',
#   "How can I fix the error 'evidently service cannot import from pyarrow import parquet as pq'?",
#   "What should I do if installing pyarrow and restarting my machine doesn't solve the issue?",
#   "Is the pyarrow module necessary for the 'evidently' service based on 'app.py'?"],
#  '03f20ec1': ['When using evidently, what does the ValueError: Incorrect item instead of a metric or metric preset was passed to Report mean?',
#   'What should I do if I encounter a ValueError when using evidently?',
#   'Why am I getting a ValueError saying incorrect item instead of a metric or metric preset was passed to Report in evidently?',
#   'What is a common reason for getting a ValueError with evidently related to metrics?',
#   'How can I fix the ValueError related to incorrect item in evidently?',
#   'Who provided the solution for fixing the evidently error?'],
#  '249726fe': ['How do I avoid an error when using RegressionQualityMetric()?',
#   'What parameter is required by RegressionQualityMetric() to function correctly?',
#   'Where should I add the target parameter for the RegressionQualityMetric() function?',
#   'What should the target parameter be when using RegressionQualityMetric()?',
#   'Who is the instructor or author for the module on RegressionQualityMetric()?'],
#  '4e492af0': ['Why do I get a ValueError for found array with 0 sample(s)?',
#   'What does the shape=(0, 6) mean in the ValueError?',
#   'Why is my training dataset empty?',
#   'How do I fix the ValueError caused by an empty array in LinearRegression?',
#   'When was the solution for the ValueError added?'],
#  '10011dc1': ['What error might occur when adding a new metric in Module 5?',
#   "What documentation should I read when I see 'target columns' or 'prediction columns' errors?",
#   "Why am I getting 'target columns' not present errors after adding a metric?",
#   'What does the DatasetCorrelationsMetric evaluate?',
#   'What should I check if I encounter errors adding metrics in Module 5?'],
#  '92fb909a': ['How do I resolve the error when logging into Grafana with default credentials?',
#   'What should I do if standard Grafana login fails?',
#   'What command fixes the standard login error in Grafana?',
#   'How can I reset the admin password in Grafana when login fails?',
#   'Which command needs to be run in the Grafana container to fix failed login?'],
#  '2b8cb640': ['Why is my Grafana chart not updating even though my metric script is running?',
#   'What refresh interval should I set in Grafana to ensure charts update frequently?',
#   'How can using the wrong timezone affect Grafana chart updates?',
#   'What two things should I check if my Grafana charts are not refreshing?',
#   'What was the original timezone value that caused issues with Grafana updates?'],
#  'd4ceab0b': ['What step should I take if Prefect server stops immediately after running the start command?',
#   "How can I resolve the issue if the Prefect server doesn't run locally?",
#   'What alternative did Erick Calderin use when the Prefect server failed to start locally?',
#   "Where did Erick report the Prefect server issue when it wouldn't run locally?",
#   'Which command was initially tried to start the Prefect server locally?'],
#  '482e575f': ["What can I do if there's no disk space left during docker compose up?",
#   'How do I resolve a no disk space left error in Docker?',
#   'What command can remove unused Docker items to free up space?',
#   'How can I view what is taking up space in Docker before pruning?',
#   'Who provided the solution for the no disk space left error in Docker?'],
#  '33e775eb': ["What should I do if I get the error 'Failed to listen on :::8080 (reason: php_network_getaddresses: getaddrinfo failed: Address family for hostname not supported)' when running docker-compose up --build?",
#   "How can I solve the error related to 'php_network_getaddresses' when using docker-compose?",
#   "Where exactly should I add the command 'php -S 0.0.0.0:8080 -t /var/www/html' to fix the listening error on port 8080?",
#   'In which section of the yml file should the command to fix the 8080 listening error be added?',
#   "Who can I contact for further assistance regarding the error 'Failed to listen on :::8080'?"],
#  '19a3d34a': ['Can we generate charts like Evidently inside Grafana?',
#   'What type of panels are available in Grafana to represent Evidently charts?',
#   'Is there a native way to quickly recreate Evidently dashboards in Grafana?',
#   'What should you do to recreate Evidently visualizations externally?',
#   'What option should be added to include everything you need for non-aggregated visuals?'],
#  '55c68f23': ["What should I do if I get an 'Unable to locate credentials' error when running localstack with kinesis?",
#   "How can I resolve the error ‘{'errorMessage': 'Unable to locate credentials', …’ from test_docker.py?",
#   "What environment variables need to be added to docker-compose.yaml to fix the 'Unable to locate credentials' error?",
#   'Is there a command I can run to configure AWS credentials for localstack with random values?',
#   'Who suggested adding AWS_ACCESS_KEY_ID and AWS_SECRET_ACCESS_KEY to the docker-compose.yaml file to fix the credentials error?'],
#  '54020f0a': ['What error might occur when creating a bucket with localstack and boto3?',
#   "What is the cause of the error 'unspecified location constraint is incompatible'?",
#   'How can you fix the IllegalLocationConstraintException when using boto3 to create a bucket?',
#   'What additional parameter must be included to avoid the region specific endpoint error in boto3?',
#   "Who added the solution for fixing the 'unspecified location constraint' error?"],
#  'b6249d2c': ['What should I do if I get the error <botocore.awsrequest.AWSRequest object at 0x7fbaf2666280> after running an AWS CLI command?',
#   'How can I fix the AWS CLI error indicating <botocore.awsrequest.AWSRequest object>?',
#   'What are the steps to resolve the error <botocore.awsrequest.AWSRequest object> when running aws s3 ls?',
#   'Can you guide me on setting the environment variables to fix the <botocore.awsrequest.AWSRequest object> error in AWS CLI?',
#   'What values should I use for AWS_DEFAULT_REGION, AWS_ACCESS_KEY_ID, and AWS_SECRET_ACCESS_KEY to fix the CLI error?'],
#  '31543d95': ["What should I check if pre-commit triggers a 'mapping values are not allowed' error at every commit?",
#   'Why are no pre-commit hooks running when I commit?',
#   "How can I fix the 'mapping values are not allowed in this context' error with pre-commit?",
#   "What could cause the 'mapping values are not allowed in this context' error in .pre-commit-config.yaml?",
#   'What specific indentation issue can cause pre-commit errors in .pre-commit-config.yaml?'],
#  'e147bbb6': ["How can I reconfigure pytest if I can't remove pytest tests?",
#   "What should I do if pytest isn't resetting after switching folders?",
#   'How do I clear pytest settings for a new testing folder?',
#   'Is there a way to reset pytest configurations without uninstalling?',
#   'Which folder should I delete to reconfigure pytest from scratch?'],
#  'dc55657f': ['How can we resolve the empty records issue in Kinesis Get Records with LocalStack?',
#   'What should be added to the get records command to fix the empty Records problem?',
#   'At which minute in video 6.3 is the empty records issue discussed?',
#   'Which AWS command option can solve the empty records problem in Kinesis with LocalStack?',
#   'What endpoint URL is used in the solution for getting Kinesis records in LocalStack?'],
#  'f6979915': ["What should I do if 'git commit' raises a utf-8 encoding error after creating a pre-commit YAML file?",
#   "What does the utf-8 encoding error look like when using 'git commit' with a pre-commit YAML file?",
#   "How can you fix the utf-8 codec can't decode byte error in a pre-commit YAML file for Git?",
#   'Who provided the solution for setting utf-8 encoding when creating a pre-commit YAML file?',
#   'What is the command to set utf-8 encoding when generating a pre-commit-config.yaml file in Powershell?'],
#  '1076a121': ["How can I troubleshoot the error 'PythonInfo' object has no attribute 'version_nodot' in my git commit with pre-commit hook?",
#   "What is the solution for the error 'PythonInfo' object has no attribute 'version_nodot' when committing with pre-commit hook?",
#   "Why does my git commit with pre-commit hook show the error 'PythonInfo' object has no attribute 'version_nodot'?",
#   "What command should I run to resolve the 'PythonInfo' object has no attribute 'version_nodot' error during git commit?",
#   "Who provided the solution to the issue 'PythonInfo' object has no attribute 'version_nodot' in Module 6?"],
#  'aa203ca7': ["What should I do when I encounter a 'module not found' error while using custom packages in my source code with pytest?",
#   'How should I structure my project if I want to avoid import errors with pytest?',
#   'What command should I use to run pytest without encountering the ‘No module named’ error?',
#   'Why does running pytest without -m result in a module not found error?',
#   'Is there an alternative to running python -m pytest to avoid import errors with custom packages?'],
#  '8b04605d': ["What should I do if I encounter 'module not found' error when using pre-commit hooks?",
#   "What is the project structure mentioned for resolving the 'No module named' error?",
#   "Which hook configuration should be used to fix the pytest 'No module named' error?",
#   "How should the run.sh script be configured to fix the 'module not found' issue?",
#   "Who added the solution for the pytest 'module not found' error in the documentation?"],
#  'a3b9af04': ['What should be done if a permission denied error occurs when executing a script file in Github Actions?',
#   'How can I resolve a permission error for a script file during Github CI action?',
#   'What is the solution for an error code 126 in Github Actions when running a script?',
#   'Which git command can add execution permission to a script file?',
#   'Who added the solution for the permission denied error in Github Actions?'],
#  'b16aae74': ['What is the recommended way to manage resource usage when running numerous containers in a docker-compose file?',
#   'How can one easily select a specific group of containers for testing in a docker-compose setup?',
#   'What should be added to the service definition to address resource management in docker-compose?',
#   'Which command flag is needed to start services using profiles in docker-compose?',
#   'Who contributed the solution for managing multiple Docker containers with profiles?'],
#  '66326a87': ['What might cause issues with integration tests and Kinesis?',
#   'Why should AWS regions match in docker-compose and local config?',
#   'How can I solve the problem of streams being created in the wrong region?',
#   'What should the AWS region be set to in ~/.aws/config?',
#   'What should AWS_DEFAULT_REGION be set to in docker-compose.yaml?'],
#  'fb3c4150': ['What version should I set for isort to fix the pre-commit command failure?',
#   'Who added the solution for the Isort pre-commit issue?',
#   'What module covers best practices in the course?',
#   'What was failing in the pre-commit command related to isort?',
#   'Which specific version of isort resolves the pre-commit failure issue?'],
#  '886d1617': ['How do I remove AWS infrastructure set up through GitHub Actions?',
#   'What is the command to initialize Terraform with a specific backend?',
#   'How can infrastructure created with CD-Deploy Action be destroyed?',
#   'What file needs to be specified to destroy AWS infrastructure with Terraform?',
#   'Who provided the solution for destroying infrastructure created via GitHub Actions?']}

# %%
doc_index = {d["id"]: d for d in documents}

# %%
final_results = []

for doc_id, questions in parsed_results.items():
    course = doc_index[doc_id]["course"]
    for q in questions:
        final_results.append((q, course, doc_id))

# %%
import pandas as pd

# %%
df = pd.DataFrame(final_results, columns=["question", "course", "document"])

# %%
df.head(2)
# Out:
#                                             question  \
# 0  What is the starting date and time of the course?
# 1  When will the first 'Office Hours' live sessio...
#
#                       course  document
# 0  data-engineering-zoomcamp  c02e79ef
# 1  data-engineering-zoomcamp  c02e79ef

# %%
df.to_csv("ground-truth-data.csv", index=False)

# %%
# !head ground-truth-data.csv
# Out:
# question,course,document
# What is the starting date and time of the course?,data-engineering-zoomcamp,c02e79ef
# When will the first 'Office Hours' live session be?,data-engineering-zoomcamp,c02e79ef
# How can I subscribe to the course's public Google Calendar?,data-engineering-zoomcamp,c02e79ef
# Where should I register before the course starts?,data-engineering-zoomcamp,c02e79ef
# Which platforms should I join for announcements and discussions?,data-engineering-zoomcamp,c02e79ef
# What are the course prerequisites?,data-engineering-zoomcamp,1f6520ca
# Are there any prerequisites I need to know before starting?,data-engineering-zoomcamp,1f6520ca
# Where can I find details about course requirements?,data-engineering-zoomcamp,1f6520ca
# Is there a list of prerequisites available for the course?,data-engineering-zoomcamp,1f6520ca
